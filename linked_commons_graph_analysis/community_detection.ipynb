# %%
import collections
import math
import os
import glob
import time
import datetime
import pickle

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy
import scipy.stats
import seaborn as sns

import networkx as nx
from networkx.algorithms import community
import graph_tool.all as gt

import cc_graph_ops

# %% [markdown]
# ## Running the Stochastic Block Model

# %% [markdown]
# We use the weighted-edge schochastic block model to generate communities within our graph. Our code is taking from the [cookbook](https://graph-tool.skewed.de/static/doc/demos/inference/inference.html) on `graph-tool`'s documentation.

# %%
INPUT_FILE = 'fdg_input_file.json'

# %%
g = cc_graph_ops.create_graph_from_file(INPUT_FILE, format='gt')

# %%
quota = 10
proportion = 0.3
min_subgraph_size = 100

# %%
licenses = list(cc_graph_ops.get_licenses(g))

# %%
subgraphs = cc_graph_ops.all_license_subgraphs(g, licenses, quota=quota, proportion=proportion)

# %%
OUTPUT_DIR = 'block_models/'

# %%
class BlockModelData:
    def __init__(self, elapsed, license, model):
        self.elapsed = elapsed
        self.license = license
        self.model = model

# %%
def write_communities(subgraphs, output_dir, min_subgraph_size):
    os.mkdir(output_dir)
    for license, subg in subgraphs.items():
        if len(list(subg.vertices())) < min_subgraph_size:
            continue
        print(license)
        tic = time.time()
        model = gt.minimize_nested_blockmodel_dl(subg, state_args=dict(recs=[subg.ep.weight],
                                                rec_types=['discrete-geometric']))
        model = model.copy(bs=model.get_bs() + [np.zeros(1)] * 4,
                            sampling = True)
        for i in range(100):
            ret = model.multiflip_mcmc_sweep(niter=10, beta=np.inf)
        toc = time.time()
        print(toc - tic)
        with open(os.path.join(output_dir, "".join(e for e in license if e.isalnum()) + '.pkl'), 'wb') as f:
            pickle.dump(BlockModelData(toc - tic, license, model), f)

# %%
## We only need to run this once
# write_communities(subgraphs, OUTPUT_DIR, min_subgraph_size)

# %%
def read_communities(output_dir, verbose=False, domains=False):
    license_communities = dict()
    for filepath in glob.glob(output_dir + "*.pkl"):
        if verbose:
            print(filepath)
        with open(filepath, 'rb') as file:
            model = pickle.load(file)
            levels = model.model.get_levels()
            communities = collections.defaultdict(list)
            for v in subgraphs[model.license].vertices():
                v_id = subgraphs[model.license].vp['id'][v]
                if domains:
                    v_id = (v_id, subgraphs[model.license].vp['provider_domain'][v])
                com_id = levels[0].get_blocks()[v]
                communities[com_id].append(v_id)
            license_communities[model.license] = communities
    return license_communities

# %%
license_communities = read_communities(OUTPUT_DIR, domains=True)

# %%
license_communities.keys()
# Out:
# dict_keys(["('by-nc', '2.0')", "('by', '4.0')", "('cc0', '1.0')", "('gpl', '2.0')", "('by-nc-sa', '3.0')", "('by-nc', '3.0')", "('by-nc-sa', '4.0')", "('pdm', '1.0')", "('by-nc-nd', '4.0')", "('by-nc-sa', '2.5')", "('by-nc', '4.0')", "('by', '3.0')", "('by-sa', '4.0')", "('by-nd', '4.0')", "('by-sa', '3.0')", "('by', '2.5')", "('by-nd', '3.0')", "('by-sa', '2.0')", "('by-nc-nd', '2.0')", "('by-nc-nd', '3.0')", "('by-sa', '2.5')", "('by-nc', '2.5')", "('by', '2.0')", "('by-nd', '2.0')", "('by-nc-nd', '2.5')", "('by-nc-sa', '2.0')"])

# %%
for license, communities in license_communities.items():
    print(license)
    print()
    for num, community in communities.items():
        # Very large communities are likely spurious
        if len(community) > 0.3 * len(list(subgraphs[license].vertices())) or len(community) > 100:
            continue
        print(len(community))
        print(community)
        print()
    print()
    print('-'*70)
    print()
# Out:
# ('by-nc', '2.0')
#
# 15
# [('schoolplaten', 'www.schoolplaten.com'), ('a-worldofwords', 'www.a-worldofwords.com'), ('timbres-bordeaux', 'www.timbres-bordeaux.fr'), ('schulbilder', 'www.schulbilder.org'), ('france-timbres', 'marcophilie.france-timbres.net'), ('educol', 'www.educol.net'), ('album-timbres', 'album-timbres.fr'), ('planchage-timbres', 'www.planchage-timbres.fr'), ('sclera', 'sclera.be'), ('infobilder', 'www.infobilder.com'), ('educima', 'www.educima.com'), ('e-timbres', 'www.marcophilie.e-timbres.net'), ('eg0', 'eg0.me'), ('mouton-rebelle', 'ego.mouton-rebelle.com'), ('onceuponabookcase', 'www.onceuponabookcase.co.uk')]
#
# 26
# [('ordinary-times', 'ordinary-times.com'), ('opb', 'www.opb.org'), ('dchauvin', 'dchauvin.fr'), ('sensorysmithfield', 'sensorysmithfield.com'), ('managementmania', 'managementmania.com'), ('oulip', 'oulip.info'), ('arborupdate', 'arborupdate.com'), ('obercom', 'obs.obercom.pt'), ('bijinkei', 'bijinkei.net'), ('sensorycities', 'www.sensorycities.com'), ('danwebb', 'blog.danwebb.net'), ('lasikuu', 'lasikuu.net'), ('redcross', 'vad.redcross.org.uk'), ('liensppo', 'liensppo.qc.ca'), ('looksgoodworkswell', 'www.looksgoodworkswell.com'), ('alt-sheff', 'alt-sheff.co.uk'), ('addition', 'obsdev.addition.pt'), ('gouv', 'www.toponymie.gouv.qc.ca'), ('somebits', 'www.somebits.com'), ('kasvukipuja', 'kasvukipuja.net'), ('changeursdemonde', 'www.changeursdemonde.net'), ('aadl', 'aadl.org'), ('harakkasyndrooma', 'harakkasyndrooma.net'), ('kultsu', 'kultsu.net'), ('suntuubi', 'anarchie.suntuubi.com'), ('ada-online', 'www.ada-online.org')]
#
#
# ----------------------------------------------------------------------
#
# ('by', '4.0')
#
# 63
# [('chaskor', 'www.chaskor.ru'), ('thumbapps', 'www.thumbapps.org'), ('show', 'www.show.me.uk'), ('webaccessibile', 'www.webaccessibile.org'), ('olivian', 'olivian.ro'), ('martinfryc', 'martinfryc.eu'), ('sajhrm', 'sajhrm.co.za'), ('gonglchuangl', 'google-developers.gonglchuangl.net'), ('informnapalm', 'informnapalm.org'), ('slides', 'slides.com'), ('rakhesh', 'rakhesh.com'), ('yorkshirecnd', 'yorkshirecnd.org.uk'), ('javiergutierrezchamorro', 'www.javiergutierrezchamorro.com'), ('web', 'web.dev'), ('journalist', 'journalist.ck.ua'), ('kaluzny', 'kaluzny.io'), ('ademar', 'blog.ademar.org'), ('mydns', 'mizugadro.mydns.jp'), ('openmrs', 'openmrs.org'), ('hatenablog', 'tricken.hatenablog.com'), ('libreplanet', 'media.libreplanet.org'), ('wikiprocedure', 'www.wikiprocedure.com'), ('equalvotes', 'equalvotes.us'), ('davejingtian', 'davejingtian.org'), ('fuchsia', 'fuchsia.dev'), ('apigee', 'docs.apigee.com'), ('mallowcollege', 'mallowcollege.ie'), ('mundorama', 'mundorama.net'), ('verborgh', 'data.verborgh.org'), ('yoppa', 'yoppa.org'), ('vvave', 'www.vvave.net'), ('hail2u', 'hail2u.net'), ('kryptera', 'kryptera.se'), ('codershood', 'www.codershood.info'), ('medium', 'medium.com'), ('ontariomathresources', 'ontariomathresources.ca'), ('badayak', 'badayak.com'), ('openbible', 'www.openbible.info'), ('herokuapp', 'blocitoff-nate.herokuapp.com'), ('poesiabinaria', 'poesiabinaria.net'), ('ijtmgh', 'www.ijtmgh.com'), ('antonioluna', 'www.antonioluna.org'), ('openspeaks', 'openspeaks.com'), ('theepochtimes', 'www.theepochtimes.com'), ('albert-schweitzer-stiftung', 'albert-schweitzer-stiftung.de'), ('fluidproject', 'wiki.fluidproject.org'), ('taichimd', 'taichimd.us'), ('alchemyofchange', 'www.alchemyofchange.net'), ('curius', 'curius.de'), ('karbobala', 'www.karbobala.com'), ('dory', 'dory.kr'), ('securityforcemonitor', 'trainingdata.securityforcemonitor.org'), ('sketchfab', 'sketchfab.com'), ('biblioblog', 'www.biblioblog.si'), ('id-libre', 'id-libre.org'), ('jser', 'jser.info'), ('adactio', 'adactio.com'), ('jchk', 'jchk.net'), ('baldanders', 'baldanders.info'), ('equalcitizens', 'equalcitizens.us'), ('chriszheng', 'chriszheng.science'), ('newtype', 'newtype.pe.kr'), ('mike-bland', 'mike-bland.com')]
#
# 87
# [('pareigis', 'jorg.pareigis.se'), ('peerconomy', 'peerconomy.org'), ('letsplayforum', 'letsplayforum.de'), ('oeglobal', 'conference.oeglobal.org'), ('selbstlernen', 'www.selbstlernen.net'), ('vorhundert', 'vorhundert.de'), ('chaotikum', 'wiki.chaotikum.org'), ('iha', 'www.iha.it'), ('joeran', 'www.joeran.de'), ('onlinenetworkofeducators', 'onlinenetworkofeducators.org'), ('oercamp', 'www.oercamp.de'), ('famvin', 'famvin.org'), ('bildungsbuch', 'www.bildungsbuch.at'), ('cogneon', 'wiki.cogneon.de'), ('pstade', 'pstade.de'), ('mapping-oer', 'mapping-oer.de'), ('oer-fachexperten', 'www.oer-fachexperten.de'), ('gender-blog', 'www.gender-blog.de'), ('berlin-brandenburg', 'bildungsserver.berlin-brandenburg.de'), ('was-ist-oer', 'www.was-ist-oer.de'), ('kristin-narr', 'kristin-narr.de'), ('creatoers', 'creatoers.de'), ('pdftalk', 'wiki.pdftalk.de'), ('alumniportal-deutschland', 'www.alumniportal-deutschland.org'), ('helmholtz', 'blogs.helmholtz.de'), ('christianfriedrich', 'blog.christianfriedrich.org'), ('aktionstage-politische-bildung', 'aktionstage-politische-bildung.net'), ('annasleben', 'www.annasleben.de'), ('schule-bw', 'www.schule-bw.de'), ('dampfcast', 'dampfcast.net'), ('routenplaner-digitale-bildung', 'routenplaner-digitale-bildung.de'), ('blog-genderopen', 'blog-genderopen.de'), ('mprove', 'photo.mprove.net'), ('meta-journal', 'meta-journal.net'), ('medienberaterbloggt', 'medienberaterbloggt.de'), ('bldg-alt-entf', 'bldg-alt-entf.de'), ('zbw-mediatalk', 'www.zbw-mediatalk.eu'), ('feierabendbier-open-education', 'feierabendbier-open-education.de'), ('matthias-andrasch', 'blog.matthias-andrasch.de'), ('edtechfactotum', 'edtechfactotum.com'), ('ruedimumenthaler', 'ruedimumenthaler.ch'), ('youngdata', 'www.youngdata.de'), ('christer', 'www.christer.io'), ('edufunk', 'edufunk.fm'), ('dotcomblog', 'dotcomblog.de'), ('lacobe', 'lacobe.de'), ('sodis', 'loern.sodis.de'), ('opengenderjournal', 'opengenderjournal.de'), ('khpape', 'khpape.blog'), ('podcampus', 'podcampus.de'), ('opengenderplatform', 'opengenderplatform.de'), ('libreas', 'libreas.eu'), ('memucho', 'memucho.de'), ('barfuss', 'www.barfuss.it'), ('cl2025', 'cl2025.de'), ('opencourseware', 'www.opencourseware.eu'), ('c-m-l', 'www.c-m-l.net'), ('podcaster', 'tele-stammtisch.podcaster.de'), ('podigee', 'unterhaltungszimmer.podigee.io'), ('tongestaltung-bildung', 'www.tongestaltung-bildung.de'), ('christianhaider', 'christianhaider.de'), ('infoeduc8r', 'infoeduc8r.com'), ('open-educational-resources', 'open-educational-resources.de'), ('forumbd', 'www.forumbd.de'), ('osconjunction', 'osconjunction.net'), ('genderforum', 'genderforum.org'), ('kupf', 'kupf.at'), ('oncampus', 'biologie.oncampus.de'), ('flavoursofopen', 'lab.flavoursofopen.science'), ('the-gaffer', 'www.the-gaffer.de'), ('schoolofschenk', 'schoolofschenk.com'), ('jointly', 'jointly.info'), ('fingal', 'data.fingal.ie'), ('sugarraybanister', 'www.sugarraybanister.de'), ('dipfblog', 'dipfblog.com'), ('ruedigerprehn', 'www.ruedigerprehn.de'), ('oerlabs', 'oerlabs.de'), ('marcel-waldvogel', 'marcel-waldvogel.ch'), ('ring-a-scientist', 'www.ring-a-scientist.org'), ('ebildungslabor', 'ebildungslabor.de'), ('o2c2', 'o2c2.org'), ('doit-europe', 'www.doit-europe.net'), ('ijab', 'ijab.de'), ('wir-machen-kinderseiten', 'wir-machen-kinderseiten.de'), ('actchange', 'lebenswertes-chemnitz.actchange.com'), ('erwachsenenbildung', 'erwachsenenbildung.at'), ('irights', 'irights.info')]
#
# 75
# [('go-fair', 'www.go-fair.org'), ('phage', 'phage.directory'), ('weecology', 'jabberwocky.weecology.org'), ('o2r', 'o2r.info'), ('slpk', 'www.slpk.sk'), ('asapbio', 'asapbio.org'), ('scienceopen', 'www.scienceopen.com'), ('research', 'research.rs'), ('svpow', 'svpow.com'), ('indiarxiv', 'indiarxiv.in'), ('openaccessindia', 'openaccessindia.org'), ('openscienceradio', 'www.openscienceradio.org'), ('graukaue', 'graukaue.eu'), ('konscience', 'www.konscience.de'), ('cjgh', 'journal.cjgh.org'), ('share-research', 'www.share-research.org'), ('bayern', 'www.gkd.bayern.de'), ('winningslowly', 'winningslowly.org'), ('coxdocs', 'www.coxdocs.org'), ('icono14', 'www.icono14.net'), ('bigpolicycanvas', 'www.bigpolicycanvas.eu'), ('topelius', 'www.topelius.fi'), ('gbv', 'dokumentation.digitalebibliothek.gbv.de'), ('otwartakultura', 'otwartakultura.org'), ('andaluciatransversal', 'blog.andaluciatransversal.com'), ('oeaw', 'sammlung.woldan.oeaw.ac.at'), ('openknowledgemaps', 'openknowledgemaps.org'), ('uni-mannheim', 'antikersport.uni-mannheim.de'), ('onerepo', 'blog.onerepo.net'), ('dublincore', 'explore.dublincore.net'), ('intereconomics', 'www.intereconomics.eu'), ('fromthebottomoftheheap', 'www.fromthebottomoftheheap.net'), ('oekom', 'ojs.oekom.de'), ('textgrid', 'textgrid.de'), ('sfdora', 'sfdora.org'), ('fossilsandshit', 'fossilsandshit.com'), ('quantixed', 'quantixed.org'), ('revistadoilct', 'revistadoilct.com.br'), ('access2perspectives', 'access2perspectives.com'), ('mu', 'rhymeswithright.mu.nu'), ('poseidomm', 'www.poseidomm.eu'), ('surveyinsights', 'surveyinsights.org'), ('cos', 'cos.io'), ('socopen', 'socopen.org'), ('cienciaaberta', 'www.cienciaaberta.net'), ('datacite', 'blog.datacite.org'), ('fwf', 'e-book.fwf.ac.at'), ('sciedu', 'www.sciedu.ca'), ('ijdc', 'ijdc.net'), ('jbrittholbrook', 'jbrittholbrook.com'), ('knowledgefutures', 'notes.knowledgefutures.org'), ('data-intelligence', 'data-intelligence.org'), ('bioverlay', 'www.bioverlay.org'), ('wikirateproject', 'wikirateproject.org'), ('jovital', 'jovital.eu'), ('besser-fragen', 'www.besser-fragen.com'), ('oaspa', 'oaspa.org'), ('bloodhound-tracker', 'bloodhound-tracker.net'), ('blucher', 'www.proceedings.blucher.com.br'), ('j-micropalaeontol', 'www.j-micropalaeontol.net'), ('michaelmann', 'michaelmann.net'), ('openuphub', 'www.openuphub.eu'), ('cgilmodena', 'www.cgilmodena.it'), ('oamediastudies', 'oamediastudies.com'), ('assaf', 'journals.assaf.org.za'), ('thewinnower', 'thewinnower.com'), ('digitalmedievalist', 'journal.digitalmedievalist.org'), ('datenschutz-schule', 'datenschutz-schule.info'), ('openinorder', 'openinorder.to'), ('ukscl', 'ukscl.ac.uk'), ('plecevo', 'www.plecevo.eu'), ('wu', 'epub.wu.ac.at'), ('thinkchecksubmit', 'thinkchecksubmit.org'), ('rossmounce', 'rossmounce.co.uk'), ('ninamvseeno', 'test.ninamvseeno.org')]
#
# 21
# [('notulaebiologicae', 'notulaebiologicae.ro'), ('introductory-sanskrit', 'www.introductory-sanskrit.com'), ('zenodo', 'zenodo.org'), ('cgiar', 'ccafs.cgiar.org'), ('peternewbury', 'peternewbury.org'), ('uj', 'denali.geo.uj.edu.pl'), ('vsb', 'advances.vsb.cz'), ('conservationevidence', 'www.conservationevidence.com'), ('rationalargumentator', 'www.rationalargumentator.com'), ('petrsu', 'rt.petrsu.ru'), ('openaire', 'www.openaire.eu'), ('uniri', 'repository.medri.uniri.hr'), ('hydroshare', 'hydroshare.org'), ('dotporterdigital', 'www.dotporterdigital.org'), ('landportal', 'www.landportal.org'), ('isu', 'ies.journals.isu.ac.ir'), ('ffos', 'repozitorij.ffos.hr'), ('galaxyproject', 'training.galaxyproject.org'), ('openrepository', 'www.openrepository.ru'), ('finna', 'kansalliskirjasto.finna.fi'), ('coolblog', 'mycoscouter.coolblog.jp')]
#
# 43
# [('tuni', 'trepo.tuni.fi'), ('ucd', 'iberian.ucd.ie'), ('archives-ouvertes', 'hal.archives-ouvertes.fr'), ('ndltd', 'www.ndltd.org'), ('africarxiv', 'info.africarxiv.org'), ('fupress', 'riviste.fupress.net'), ('openelectiondata', 'openelectiondata.net'), ('dainst', 'opencontext.dainst.org'), ('mpg', 'abvd.shh.mpg.de'), ('rse', 'rse.ac.uk'), ('gesis', 'mda.gesis.org'), ('vtt', 'cris.vtt.fi'), ('degruyter', 'www.degruyter.com'), ('uliege', 'donum.uliege.be'), ('dioe', 'dioe.at'), ('sajs', 'www.sajs.co.za'), ('textpraxis', 'textpraxis.net'), ('logainm', 'www.logainm.ie'), ('uni-goettingen', 'subtiwiki.uni-goettingen.de'), ('openbiblio', 'badge.openbiblio.eu'), ('laji', 'laji.blog'), ('ideca', 'ideca.gov.co'), ('aip', 'aip.dev'), ('horizon-magazine', 'horizon-magazine.eu'), ('questonline', 'questonline.org.za'), ('alt', 'altc.alt.ac.uk'), ('unr', 'fcpolit.unr.edu.ar'), ('elsevierpure', 'uni-salzburg.elsevierpure.com'), ('donnalanclos', 'www.donnalanclos.com'), ('compress', 'compress.edu.pl'), ('socialmediaforlearning', 'socialmediaforlearning.com'), ('tib', 'handbuch.tib.eu'), ('soton', 'eprints.soton.ac.uk'), ('warwick', 'blogs.warwick.ac.uk'), ('ukri', 'mrc.ukri.org'), ('evidencenetwork', 'evidencenetwork.ca'), ('evoio', 'www.evoio.org'), ('helsinki', 'helda.helsinki.fi'), ('wind-energ-sci', 'www.wind-energ-sci.net'), ('cplong', 'cplong.org'), ('escholarship', 'escholarship.org'), ('plymouth', 'pearl.plymouth.ac.uk'), ('auth', 'www.sci.auth.gr')]
#
# 70
# [('narodycka-gromada', 'narodycka-gromada.gov.ua'), ('hrestivska-gromada', 'hrestivska-gromada.gov.ua'), ('lisovogrynivecka-rada', 'lisovogrynivecka-rada.gov.ua'), ('gorodocka-gromada', 'gorodocka-gromada.gov.ua'), ('dsbt', 'dsbt.gov.ua'), ('mk-otg', 'mk-otg.gov.ua'), ('brusylivska-gromada', 'brusylivska-gromada.gov.ua'), ('derazhnenska-gromada', 'derazhnenska-gromada.gov.ua'), ('khust-rda', 'osv.khust-rda.gov.ua'), ('grebinka-rayrada', 'grebinka-rayrada.gov.ua'), ('pidgaecka-rayrada', 'pidgaecka-rayrada.gov.ua'), ('lmr', 'lmr.gov.ua'), ('stepanivska-gromada', 'stepanivska-gromada.gov.ua'), ('trybuhivska-gromada', 'trybuhivska-gromada.gov.ua'), ('pokrovsk-rada', 'quality.pokrovsk-rada.gov.ua'), ('mukrayon', 'mukrayon.gov.ua'), ('chornoostrivska-otg', 'chornoostrivska-otg.gov.ua'), ('drabivrada', 'demky.drabivrada.gov.ua'), ('kalanchacka-gromada', 'kalanchacka-gromada.gov.ua'), ('pyryatynska-rayrada', 'pyryatynska-rayrada.gov.ua'), ('tyachiv-city', 'tyachiv-city.gov.ua'), ('tupychiv-rada', 'tupychiv-rada.gov.ua'), ('bilogirska-gromada', 'bilogirska-gromada.gov.ua'), ('nabutivska-gromada', 'nabutivska-gromada.gov.ua'), ('satanivska-gromada', 'satanivska-gromada.gov.ua'), ('prybuzhanivska-gromada', 'prybuzhanivska-gromada.gov.ua'), ('if', 'e-consultation.burshtyn-rada.if.gov.ua'), ('vberez', 'vberez.gov.ua'), ('volochyska-gromada', 'volochyska-gromada.gov.ua'), ('solonkivska-gromada', 'solonkivska-gromada.gov.ua'), ('rv', 'www.rv.gov.ua'), ('chechelnik-rada', 'chechelnik-rada.gov.ua'), ('chemerovecka-gromada', 'chemerovecka-gromada.gov.ua'), ('zdolbun', 'zdolbun.gov.ua'), ('mva', 'mva.gov.ua'), ('sm', 'sm.gov.ua'), ('zhdanivska-gromada', 'zhdanivska-gromada.gov.ua'), ('uvaga', 'uvaga.gov.ua'), ('irshavaotg', 'irshavaotg.gov.ua'), ('nedr-rr', 'terny.nedr-rr.gov.ua'), ('kyiv-oblosvita', 'www.kyiv-oblosvita.gov.ua'), ('sqe', 'sqe.gov.ua'), ('semenivka-gromada', 'semenivka-gromada.gov.ua'), ('staroushytska-gromada', 'staroushytska-gromada.gov.ua'), ('zt', 'oz.zt.gov.ua'), ('zoda', 'www.zoda.gov.ua'), ('yampolrada', 'yampolrada.gov.ua'), ('chegromada', 'chegromada.gov.ua'), ('monrada', 'monrada.gov.ua'), ('st-bogorodchany-gromada', 'st-bogorodchany-gromada.gov.ua'), ('nedrygaylivska-gromada', 'nedrygaylivska-gromada.gov.ua'), ('dunaevecka-gromada', 'dunaevecka-gromada.gov.ua'), ('novoslobidska-gromada', 'novoslobidska-gromada.gov.ua'), ('gaysin-rda', 'gaysin-rda.gov.ua'), ('nrrada', 'nrrada.org.ua'), ('carpathia', 'carpathia.gov.ua'), ('sies', 'sies.gov.ua'), ('volrda', 'volrda.gov.ua'), ('sylapravdy', 'sylapravdy.com'), ('holmsr', 'holmsr.gov.ua'), ('narkevycka-gromada', 'narkevycka-gromada.gov.ua'), ('viytovecka-gromada', 'viytovecka-gromada.gov.ua'), ('kryzh', 'kryzh.gov.ua'), ('velykogaivska-gromada', 'velykogaivska-gromada.gov.ua'), ('zaraz', 'zaraz.info'), ('kuznetsovsk-rada', 'kuznetsovsk-rada.gov.ua'), ('ecology-kievoblast', 'ecology-kievoblast.com.ua'), ('hmrayrada', 'hmrayrada.gov.ua'), ('krasnopilska-gromada', 'krasnopilska-gromada.gov.ua'), ('kolybaivska-gromada', 'kolybaivska-gromada.gov.ua')]
#
# 100
# [('partyzan-rada', 'partyzan-rada.gov.ua'), ('rotmistrivska-gromada', 'rotmistrivska-gromada.gov.ua'), ('pidvolochyska-gromada', 'pidvolochyska-gromada.gov.ua'), ('lepetykha-rda', 'lepetykha-rda.gov.ua'), ('kozova-rayrada', 'kozova-rayrada.gov.ua'), ('bobrynecka-rayrada', 'bobrynecka-rayrada.gov.ua'), ('mkocubynska-gromada', 'mkocubynska-gromada.gov.ua'), ('ukrstat', 'ukrstat.org'), ('kp-rda', 'kp-rda.gov.ua'), ('pidvolochyska-rada', 'pidvolochyska-rada.gov.ua'), ('volovec-miskrada', 'volovec-miskrada.gov.ua'), ('yaremcha-miskrada', 'yaremcha-miskrada.gov.ua'), ('gnivan-miskrada', 'gnivan-miskrada.gov.ua'), ('kolkyrada', 'kolkyrada.gov.ua'), ('turka-mrada', 'turka-mrada.gov.ua'), ('semenivkrada', 'semenivkrada.gov.ua'), ('dp', 'vyshneve.otg.dp.gov.ua'), ('litin-rada', 'litin-rada.gov.ua'), ('varvynska-gromada', 'varvynska-gromada.gov.ua'), ('yagotynska-rayrada', 'yagotynska-rayrada.gov.ua'), ('hadiach-rada', 'hadiach-rada.gov.ua'), ('vyshniv-rada', 'human.vyshniv-rada.gov.ua'), ('dei', 'azov.dei.gov.ua'), ('gp', 'link.gp.lib.mi.us'), ('zvenrda', 'zvenrda.gov.ua'), ('crl', 'blyznuky.crl.org.ua'), ('sharrayrada', 'rda.sharrayrada.gov.ua'), ('vertiivska-gromada', 'vertiivska-gromada.gov.ua'), ('horolska-rayrada', 'horolska-rayrada.gov.ua'), ('pavlivska-gromada', 'pavlivska-gromada.gov.ua'), ('mogpod-rayrada', 'mogpod-rayrada.gov.ua'), ('mtu', 'mtu.gov.ua'), ('uman-rda', 'uman-rda.gov.ua'), ('liubech-gromada', 'liubech-gromada.gov.ua'), ('kornyn-gromada', 'kornyn-gromada.gov.ua'), ('classdojo', 'www.classdojo.com'), ('gorodnycka-gromada', 'gorodnycka-gromada.gov.ua'), ('pervomayska-rayrada', 'pervomayska-rayrada.gov.ua'), ('nemovycka-gromada', 'nemovycka-gromada.gov.ua'), ('davr', 'www.davr.gov.ua'), ('zvanivska-gromada', 'zvanivska-gromada.gov.ua'), ('pryiutivka-community', 'pryiutivka-community.gov.ua'), ('kulykivska-gromada', 'kulykivska-gromada.gov.ua'), ('novgorodka-rayrada', 'novgorodka-rayrada.gov.ua'), ('zavodska-gromada', 'zavodska-gromada.gov.ua'), ('rokytne-rayrada', 'rokytne-rayrada.gov.ua'), ('polyanska-gromada', 'osvita.polyanska-gromada.gov.ua'), ('evo', 'evo.im'), ('velyka-bagachka-rada', 'velyka-bagachka-rada.gov.ua'), ('hmilnycka-gromada', 'hmilnycka-gromada.gov.ua'), ('dubivska-gromada', 'dubivska-gromada.gov.ua'), ('husiatyn-osvita', 'husiatyn-osvita.gov.ua'), ('pidgayci-gromada', 'pidgayci-gromada.gov.ua'), ('vkopanivska-gromada', 'vkopanivska-gromada.gov.ua'), ('kam-buzka-rayrada', 'kam-buzka-rayrada.gov.ua'), ('semenivska-gromada', 'semenivska-gromada.gov.ua'), ('skorohodivska-gromada', 'skorohodivska-gromada.gov.ua'), ('zvir', 'www.zvir.zt.ua'), ('zhrda', 'zhrda.gov.ua'), ('yakushynecka-gromada', 'yakushynecka-gromada.gov.ua'), ('nedogarkivska-gromada', 'nedogarkivska-gromada.gov.ua'), ('khryst-rda', 'khryst-rda.gov.ua'), ('mashivka-rayrada', 'mashivka-rayrada.gov.ua'), ('baranynci-osvita', 'baranynci-osvita.gov.ua'), ('biloteg', 'biloteg.org.ua'), ('novoznamyanska-gromada', 'novoznamyanska-gromada.gov.ua'), ('trostyanecka-rayrada', 'trostyanecka-rayrada.gov.ua'), ('lysyanska-gromada', 'lysyanska-gromada.gov.ua'), ('novoavramivska-gromada', 'novoavramivska-gromada.gov.ua'), ('yagotyn-rda', 'yagotyn-rda.gov.ua'), ('koblivska-gromada', 'koblivska-gromada.gov.ua'), ('pischanka-rayrada', 'pischanka-rayrada.gov.ua'), ('zvenrada', 'zvenrada.gov.ua'), ('shabivska-gromada', 'shabivska-gromada.gov.ua'), ('irc', 'stud.irc.org.ua'), ('baturyn-rada', 'baturyn-rada.gov.ua'), ('chaplynska-gromada', 'chaplynska-gromada.gov.ua'), ('nemyriv-rda', 'nemyriv-rda.gov.ua'), ('krz', 'rayrada.krz.gov.ua'), ('volnovaska-rayrada', 'volnovaska-rayrada.gov.ua'), ('andriivka-miskrada', 'andriivka-miskrada.gov.ua'), ('mvs', 'docs.mvs.org'), ('horoshihv-rada', 'horoshihv-rada.gov.ua'), ('selrada', 'biloluck.selrada.org.ua'), ('tyvriv-miskrada', 'tyvriv-miskrada.gov.ua'), ('dn', 'dn.gov.ua'), ('ustyluzka-gromada', 'ustyluzka-gromada.gov.ua'), ('semenivsca-gromada', 'semenivsca-gromada.gov.ua'), ('vnovosilka-rayrada', 'vnovosilka-rayrada.g ...
#
# 15
# [('jlsrf', 'jlsrf.org'), ('knowledgeinnovation', 'knowledgeinnovation.eu'), ('pages-osm', 'ftp.pages-osm.org'), ('bibliophilevirtuallibrary', 'bibliophilevirtuallibrary.com'), ('pastglobalchanges', 'www.pastglobalchanges.org'), ('joewheaton', 'etal.joewheaton.org'), ('korpus', 'metashare.korpus.sk'), ('rroij', 'www.rroij.com'), ('librarydbc', 'www.librarydbc.com'), ('imedpub', 'primarycare.imedpub.com'), ('tatup', 'tatup.de'), ('ubiquitypress', 'ijosts.ubiquitypress.com'), ('nordicopenaccess', 'press.nordicopenaccess.no'), ('biospecter', 'www.biospecter.com'), ('sparceurope', 'sparceurope.org')]
#
# 37
# [('atthebookshelf', 'atthebookshelf.com'), ('informationrightsandwrongs', 'informationrightsandwrongs.com'), ('businesses', 'www.businesses.com.au'), ('meeplelikeus', 'www.meeplelikeus.co.uk'), ('openaccessweek', 'www.openaccessweek.org'), ('paleoaerie', 'paleoaerie.org'), ('fightaging', 'www.fightaging.org'), ('asta', 'assist.asta.edu.au'), ('fabiusmaximus', 'fabiusmaximus.com'), ('pressenza', 'www.pressenza.com'), ('westburn-publishers', 'www.westburn-publishers.com'), ('formulasearchengine', 'demo.formulasearchengine.com'), ('theconversation', 'theconversation.com'), ('hpluspedia', 'hpluspedia.org'), ('climateimpactnews', 'climateimpactnews.com'), ('aineetonkulttuuriperinto', 'wiki.aineetonkulttuuriperinto.fi'), ('myouanji', 'www.myouanji.com'), ('fluids', 'fluids.ac.uk'), ('globaldetentionproject', 'www.globaldetentionproject.org'), ('nvl', 'nvl.org'), ('flacso', 'relacso.flacso.edu.mx'), ('goodmedicine', 'www.goodmedicine.org.uk'), ('earthzine', 'earthzine.org'), ('duraspace', 'duraspace.org'), ('lyrasis', 'wiki.lyrasis.org'), ('desenchufados', 'desenchufados.net'), ('wellcomelibrary', 'wellcomelibrary.org'), ('choosehelp', 'm.choosehelp.com'), ('europeanhobbessociety', 'www.europeanhobbessociety.org'), ('crimejusticejournal', 'www.crimejusticejournal.com'), ('dailybulletin', 'www.dailybulletin.com.au'), ('nls', 'digital.nls.uk'), ('bepress', 'works.bepress.com'), ('mattwilkens', 'mattwilkens.com'), ('ammo', 'ammo.com'), ('fibreculturejournal', 'twentyfour.fibreculturejournal.org'), ('egu', 'imaggeo.egu.eu')]
#
# 65
# [('frankenbook', 'www.frankenbook.org'), ('ourland', 'ourland.tv'), ('refreshingbones', 'www.refreshingbones.com'), ('chrisdeluca', 'www.chrisdeluca.me'), ('transnewguinea', 'transnewguinea.org'), ('mirr4u', 'seblog.mirr4u.com'), ('pages', 'edu3d.pages.it'), ('ubuntu', 'wiki.ubuntu.cz'), ('diseasesandconditions', 'diseasesandconditions.net'), ('knative', 'knative.dev'), ('theycreateworlds', 'podcast.theycreateworlds.com'), ('hoer-mal', 'hoer-mal.net'), ('ort', 'revistas.ort.edu.uy'), ('hotwhopper', 'blog.hotwhopper.com'), ('ornamentum', 'ornamentum.app'), ('nijest', 'nijest.com'), ('unoetre', 'www.unoetre.it'), ('pustopoljina', 'pustopoljina.net'), ('historyhop', 'historyhop.com'), ('homeiswheremyheartis', 'www.homeiswheremyheartis.net'), ('corpus-musicae-ottomanicae', 'corpus-musicae-ottomanicae.de'), ('dcmwfmmmu', 'dcmwfmmmu.com'), ('silvestre', 'israel.silvestre.fr'), ('phcogj', 'www.phcogj.com'), ('swift', 'swift.org'), ('g', 'www.g.camp'), ('opendaylight', 'ask.opendaylight.org'), ('lubuntu', 'lubuntu.net'), ('nomiot', 'nomiot.com.ng'), ('ihacom', 'www.ihacom.cn'), ('stepreo', 'stepreo.co.uk'), ('abudhabienv', 'www.abudhabienv.ae'), ('the-cryosphere-discuss', 'www.the-cryosphere-discuss.net'), ('scssoft', 'blog.scssoft.com'), ('fullcirclemagazine', 'fullcirclemagazine.org'), ('xn--blickzurcknachvorn-t6b', 'www.xn--blickzurcknachvorn-t6b.net'), ('blokspeed', 'blokspeed.net'), ('travelcomparator', 'www.travelcomparator.com'), ('edpolicyinca', 'edpolicyinca.org'), ('dev', 'dev.re.kr'), ('com', 'www.iha.com.de'), ('salamanca', 'www.salamanca.school'), ('tscpl', 'link.tscpl.org'), ('buildingupgradefinance', 'buildingupgradefinance.net.au'), ('anygator', 'uk.anygator.com'), ('kogistateuniversity', 'oer.kogistateuniversity.edu.ng'), ('studiogalago', 'www.studiogalago.com'), ('michalspacek', 'www.michalspacek.com'), ('teknoaxe', 'teknoaxe.com'), ('momentosdeevasion', 'www.momentosdeevasion.com'), ('screendancejournal', 'screendancejournal.org'), ('dayofgeography', 'www.dayofgeography.com'), ('ganpatjithakor', 'www.ganpatjithakor.in'), ('completecollegegeorgia', 'afternext.completecollegegeorgia.org'), ('johnpapa', 'johnpapa.net'), ('prmacademy', 'prmacademy.org'), ('treewas', 'treewas.org'), ('pvpm', 'www.pvpm.uz'), ('topmaker', 'projects.topmaker.kr'), ('rinabrundu', 'rinabrundu.com'), ('hansenpartnership', 'blog.hansenpartnership.com'), ('almosthacker', 'almosthacker.com'), ('nilswommelsdorf', 'nilswommelsdorf.de'), ('maleraffine', 'www.maleraffine.com'), ('preservegroveisle', 'preservegroveisle.com')]
#
# 12
# [('doaj', 'doaj.org'), ('uni-regensburg', 'epub.uni-regensburg.de'), ('lbp', 'oldisrj.lbp.world'), ('sdiabeticnephropathy', 'www.sdiabeticnephropathy.com'), ('ijifactor', 'ijifactor.com'), ('crossref', 'crossmark.crossref.org'), ('kemenag', 'jurnallektur.kemenag.go.id'), ('nitku', 'nitku.net'), ('esjindex', 'esjindex.org'), ('mendeley', 'data.mendeley.com'), ('openjournalsystems', 'ojs3modern17.openjournalsystems.com'), ('openjournaltheme', 'demo.openjournaltheme.com')]
#
# 75
# [('utfpr', 'repositorio.roca.utfpr.edu.br'), ('uanl', 'www.wiki.uanl.mx'), ('ufba', 'www.portaleventos.mus.ufba.br'), ('ici', 'rria.ici.ro'), ('inecol', 'azm.ojs.inecol.mx'), ('rjp', 'rjp.com.ro'), ('espm', 'dialogo.espm.br'), ('uema', 'ppg.revistas.uema.br'), ('plm', 'ejurnal.plm.ac.id'), ('cscanada', 'cscanada.org'), ('uobaghdad', 'bsj.uobaghdad.edu.iq'), ('pucrs', 'revistaseletronicas.pucrs.br'), ('imed', 'seer.imed.edu.br'), ('masterhpc', 'wiki.masterhpc.es'), ('umpo', 'journal.umpo.ac.id'), ('ijirae', 'ijirae.com'), ('pertanian', 'ejurnal.litbang.pertanian.go.id'), ('ojsdemo', 'ojsdemo.com'), ('exelearning', 'exelearning.net'), ('pucsp', 'revistas.pucsp.br'), ('ubi', 'ojs.labcom-ifp.ubi.pt'), ('ufpel', 'periodicos.ufpel.edu.br'), ('internationalconference', 'internationalconference.net'), ('unud', 'ojs.unud.ac.id'), ('pleroma', 'pleroma.social'), ('uajy', 'ojs.uajy.ac.id'), ('unicatolicaquixada', 'publicacoesacademicas.unicatolicaquixada.edu.br'), ('unnes', 'journal.unnes.ac.id'), ('umsida', 'ojs.umsida.ac.id'), ('cecierj', 'eademfoco.cecierj.edu.br'), ('ufg', 'www.revistas.ufg.br'), ('uff', 'www.revistasg.uff.br'), ('elitesportpsy', 'www.elitesportpsy.org.au'), ('ufv', 'ddfv.ufv.es'), ('ecrcentral', 'ecrcentral.org'), ('macrothink', 'www.macrothink.org'), ('iobmresearch', 'journals.iobmresearch.com'), ('fjmu', 'link-springer-com-443.webvpn.fjmu.edu.cn'), ('unja', 'repository.unja.ac.id'), ('apez', 'www.rpz.apez.pt'), ('ijiris', 'ijiris.com'), ('fumec', 'www.fumec.br'), ('saudeemdebate', 'revista.saudeemdebate.org.br'), ('emnuvens', 'revistadaanpoll.emnuvens.com.br'), ('sbmu', 'journals.sbmu.ac.ir'), ('potensi-utama', 'elearning.potensi-utama.ac.id'), ('irjcs', 'irjcs.com'), ('syekhnurjati', 'www.syekhnurjati.ac.id'), ('colmex', 'historiamexicana.colmex.mx'), ('wikirate', 'wikirate.org'), ('ijstr', 'www.ijstr.org'), ('unilak', 'journal.unilak.ac.id'), ('rieoei', 'rieoei.org'), ('nccd', 'www.nccd.edu.au'), ('ufs', 'journals.ufs.ac.za'), ('abralic', 'revista.abralic.org.br'), ('ifgoiano', 'www.ifgoiano.edu.br'), ('rjid', 'rjid.com.ro'), ('anpad', 'rac.anpad.org.br'), ('darmajaya', 'jurnal.darmajaya.ac.id'), ('salvarojeducacion', 'www.salvarojeducacion.com'), ('fundaj', 'periodicos.fundaj.gov.br'), ('uft', 'sistemas.uft.edu.br'), ('uffs', 'periodicos.uffs.edu.br'), ('unri', 'conference.unri.ac.id'), ('unifesp', 'periodicos.unifesp.br'), ('ufsc', 'periodicos.ufsc.br'), ('ums', 'journals.ums.ac.id'), ('ufjf', 'repositorio.ufjf.br:8080'), ('ufmg', 'periodicos.ufmg.br'), ('jpahs', 'jpahs.edu.np'), ('disasteravoidanceexperts', 'disasteravoidanceexperts.com'), ('e-tsuyama', 'machi.e-tsuyama.com'), ('romulaizerpardo', 'romulaizerpardo.com'), ('revenf', 'blog.revenf.org')]
#
# 86
# [('undergroundreporter', 'undergroundreporter.org'), ('hackthematrix', 'www.hackthematrix.it'), ('naturalblaze', 'www.naturalblaze.com'), ('brandonturbeville', 'www.brandonturbeville.com'), ('consciouslifenews', 'consciouslifenews.com'), ('peppercarrot', 'www.peppercarrot.com'), ('governamerica', 'governamerica.com'), ('medt', 'www.medt.com.es'), ('procsee', 'procsee.eu'), ('sciencepg', 'sciencepg.com'), ('evolveandascend', 'www.evolveandascend.com'), ('captain-planet', 'www.captain-planet.net'), ('awakeandaware', 'awakeandaware.ca'), ('hsj', 'www.hsj.gr'), ('ticadine', 'btl.ticadine.com'), ('hsprj', 'www.hsprj.com'), ('ascensionwithearth', 'www.ascensionwithearth.com'), ('openlibraryfoundation', 'openlibraryfoundation.org'), ('encod', 'encod.org'), ('blackysburrow', 'blackysburrow.com'), ('thelibertybeacon', 'www.thelibertybeacon.com'), ('gundampodcast', 'gundampodcast.com'), ('ufo-spain', 'www.ufo-spain.com'), ('farmatoxicol', 'www.farmatoxicol.com'), ('acmicrob', 'www.acmicrob.com'), ('fundacionsustrai', 'fundacionsustrai.org'), ('actarheuma', 'www.actarheuma.com'), ('decacs-inc', 'decacs-inc.com'), ('thedailycoin', 'thedailycoin.org'), ('mpsc', 'seer.mpsc.mp.br'), ('nofakenews', 'nofakenews.net'), ('jneuro', 'www.jneuro.com'), ('dcclothesline', 'www.dcclothesline.com'), ('jewworldorder', 'www.jewworldorder.org'), ('ibelieveinmothernature', 'www.ibelieveinmothernature.com'), ('fhecker', 'fhecker.me'), ('phoenixregenetics', 'www.phoenixregenetics.org'), ('activistpost', 'www.activistpost.com'), ('positivetruenews', 'positivetruenews.com'), ('aclr', 'www.aclr.com.es'), ('thecryptosphere', 'thecryptosphere.com'), ('lightonconspiracies', 'lightonconspiracies.com'), ('sgemworld', 'ssa.sgemworld.at'), ('collective-spark', 'www.collective-spark.xyz'), ('thetrumpimpeachment', 'forum.thetrumpimpeachment.com'), ('wikihussain', 'fa.wikihussain.com'), ('theactivetimes', 'www.theactivetimes.com'), ('themindunleashed', 'themindunleashed.com'), ('science-ofthe-soul', 'www.science-ofthe-soul.com'), ('wearechange', 'wearechange.org'), ('openheartedrebellion', 'openheartedrebellion.com'), ('archivesofmedicine', 'www.archivesofmedicine.com'), ('acanceresearch', 'www.acanceresearch.com'), ('theskygirl', 'theskygirl.com'), ('theaegisalliance', 'theaegisalliance.com'), ('gergolippai', 'gergolippai.com'), ('dnewshq', 'dnewshq.com'), ('philosophicalanthropology', 'www.philosophicalanthropology.net'), ('nationandstate', 'nationandstate.com'), ('exopoliticsindia', 'www.exopoliticsindia.in'), ('thedailysheeple', 'www.thedailysheeple.com'), ('whydontyoutrythis', 'www.whydontyoutrythis.com'), ('theantimedia', 'theantimedia.com'), ('abundanthope', 'abundanthope.net'), ('k12engineering', 'k12engineering.net'), ('affiliatejedeye', 'affiliatejedeye.com'), ('renegadetribune', 'www.renegadetribune.com'), ('thedailymeal', 'www.thedailymeal.com'), ('viw', 'www.viw.com.au'), ('oom2', 'www.oom2.com'), ('freeukrainenow', 'freeukrainenow.org'), ('phillipschneider', 'phillipschneider.com'), ('archivosdemedicina', 'www.archivosdemedicina.com'), ('anonhq', 'anonhq.com'), ('soundofheart', 'soundofheart.org'), ('jusurgery', 'www.jusurgery.com'), ('zeitoon', 'www.zeitoon.org'), ('learntowork', 'learntowork.eu'), ('bitchute', 'www.bitchute.com'), ('fisheriessciences', 'www.fisheriessciences.com'), ('jbiomeds', 'www.jbiomeds.com'), ('transbiomedicine', 'www.transbiomedicine.com'), ('wakingtimes', 'www.wakingtimes.com'), ('newspronto', 'www.newspronto.com'), ('apprenticeshipq', 'apprenticeshipq.eu'), ('immunologyresearchjournal', 'www.immunologyresearchjournal.com')]
#
# 71
# [('acsima', 'irs.acsima.com'), ('novoguyvynske-miskrada', 'novoguyvynske-miskrada.gov.ua'), ('vasylkovecka-gromada', 'vasylkovecka-gromada.gov.ua'), ('gannopilska-gromada', 'gannopilska-gromada.gov.ua'), ('kazanka-gromada', 'kazanka-gromada.gov.ua'), ('bilenke-silrada', 'bilenke-silrada.gov.ua'), ('zomvo', 'zomvo.gov.ua'), ('berezanska-gromada', 'berezanska-gromada.gov.ua'), ('smila-rada', 'www.smila-rada.gov.ua'), ('drabiv-rda', 'drabiv-rda.gov.ua'), ('irda', 'www.irda.gov.ua'), ('tereblechenska-gromada', 'tereblechenska-gromada.gov.ua'), ('grygorivska-gromada', 'grygorivska-gromada.gov.ua'), ('lohvica-rayrada', 'lohvica-rayrada.gov.ua'), ('eco-bukovina', 'www.eco-bukovina.com.ua'), ('svalyava-osvita', 'svalyava-osvita.gov.ua'), ('grebinka-osvita', 'grebinka-osvita.gov.ua'), ('ptu', 'kotelva54.ptu.in.ua'), ('rada', 'mportal.rada.gov.ua'), ('bilche-zolotecka-gromada', 'bilche-zolotecka-gromada.gov.ua'), ('tomrda', 'tomrda.gov.ua'), ('osv', 'mankiv.osv.org.ua'), ('iotg', 'iotg.gov.ua'), ('kom-zoryanska-gromada', 'kom-zoryanska-gromada.gov.ua'), ('gromada', 'bilozirska.gromada.org.ua'), ('slavska-gromada', 'slavska-gromada.gov.ua'), ('klishkovetska-gromada', 'klishkovetska-gromada.gov.ua'), ('school', 'velyka-pysarivka.school.org.ua'), ('economy-zt', 'economy-zt.gov.ua'), ('vnrda', 'new.vnrda.gov.ua'), ('nar-rda', 'nar-rda.gov.ua'), ('bobrynecka-gromada', 'bobrynecka-gromada.gov.ua'), ('berestivska-gromada', 'berestivska-gromada.gov.ua'), ('orzhyca-rayrada', 'orzhyca-rayrada.gov.ua'), ('vashkovetska-gromada', 'vashkovetska-gromada.gov.ua'), ('vashkivetska-gromada', 'vashkivetska-gromada.gov.ua'), ('rudkivska-gromada', 'rudkivska-gromada.gov.ua'), ('kucurubska-gromada', 'kucurubska-gromada.gov.ua'), ('raygorod-otg', 'raygorod-otg.gov.ua'), ('kbmr', 'kbmr.gov.ua'), ('stsaltiv', 'osvita.stsaltiv.gov.ua'), ('pishanska-gromada', 'pishanska-gromada.gov.ua'), ('shsrada', 'shsrada.gov.ua'), ('nedoboivska-gromada', 'nedoboivska-gromada.gov.ua'), ('uzhgorod-osvita', 'uzhgorod-osvita.gov.ua'), ('uzh-rda', 'uzh-rda.gov.ua'), ('rozhrada', 'rozhrada.gov.ua'), ('osypenkivska-gromada', 'osypenkivska-gromada.gov.ua'), ('zhovtanetska-gromada', 'edu.zhovtanetska-gromada.gov.ua'), ('chornuhynska-gromada', 'chornuhynska-gromada.gov.ua'), ('vberz-osvita', 'vberz-osvita.gov.ua'), ('ormr', 'ormr.gov.ua'), ('krolevec-osvita', 'yaroslavec.krolevec-osvita.gov.ua'), ('kovelska-rayrada', 'kovelska-rayrada.gov.ua'), ('mashivka-rada', 'mashivka-rada.gov.ua'), ('selyatynska-gromada', 'selyatynska-gromada.gov.ua'), ('krupetska-gromada', 'krupetska-gromada.gov.ua'), ('zmiev-rayrada', 'zmiev-rayrada.gov.ua'), ('girsivska-gromada', 'girsivska-gromada.gov.ua'), ('hodorivska-gromada', 'hodorivska-gromada.gov.ua'), ('koropecka-rada', 'koropecka-rada.gov.ua'), ('talgromada', 'talgromada.gov.ua'), ('shumska-gromada', 'osv.shumska-gromada.gov.ua'), ('koropska-gromada', 'koropska-gromada.gov.ua'), ('malinivska-sr', 'malinivska-sr.gov.ua'), ('pererislyanska-gromada', 'pererislyanska-gromada.gov.ua'), ('vynogradivska-gromada', 'vynogradivska-gromada.gov.ua'), ('tav', 'tav.gov.ua'), ('krr', 'dmaharinci.krr.gov.ua'), ('tulchyn-osvita', 'tulchyn-osvita.gov.ua'), ('rda-hm', 'vkt.rda-hm.gov.ua')]
#
# 30
# [('rea', 'vest.rea.ru'), ('kemsu', 'vestnik.kemsu.ru'), ('gov39', 'mamonovo.gov39.ru'), ('ssau', 'journals.ssau.ru'), ('tjponline', 'www.tjponline.org'), ('vestnik-mgou', 'vestnik-mgou.ru'), ('rtyva', 'rtyva.ru'), ('zhouyichu', 'zhouyichu.com'), ('caribdis', 'caribdis.net'), ('bookfest', 'bookfest.by'), ('dogonlanguages', 'dogonlanguages.org'), ('expeducation', 'expeducation.ru'), ('science-philosophy', 'science-philosophy.ru'), ('kanskadm', 'kanskadm.ru'), ('glottolog', 'glottolog.org'), ('applied-research', 'www.applied-research.ru'), ('sk', 'sk.ru'), ('admsoln', 'admsoln.ru'), ('open-lesson', 'open-lesson.net'), ('mstuca', 'avia.mstuca.ru'), ('evestnik-mgou', 'evestnik-mgou.ru'), ('xn--90anlfbebar6i', 'xn--80ahclcogc6ci4h.xn--90anlfbebar6i.xn--p1ai'), ('clld', 'tsammalex.clld.org'), ('outdooractive', 'www.outdooractive.com'), ('eduherald', 'eduherald.ru'), ('elpub', 'ispranproceedings.elpub.ru'), ('gov', 'opendata.gov.cz'), ('abvpress', 'oncourology.abvpress.ru'), ('vurpo', 'ratakm.vurpo.fi'), ('ajapaik', 'ajapaik.ee')]
#
# 40
# [('tet', 'tet.gov.ua'), ('nnik-rada', 'nnik-rada.gov.ua'), ('preobrazhenska-gromada', 'preobrazhenska-gromada.gov.ua'), ('skolivska-rada', 'skolivska-rada.gov.ua'), ('mangushska-rda', 'mangushska-rda.gov.ua'), ('radehiv-rayrada', 'radehiv-rayrada.gov.ua'), ('gayvoron-rayrada', 'gayvoron-rayrada.gov.ua'), ('tlumacka-gromada', 'tlumacka-gromada.gov.ua'), ('nazk', 'nazk.gov.ua'), ('avia', 'avia.gov.ua'), ('zhovkivska-rayrada', 'zhovkivska-rayrada.gov.ua'), ('minjust', 'minjust.gov.ua'), ('radazhashkiv', 'radazhashkiv.gov.ua'), ('mk-rayrada', 'mk-rayrada.gov.ua'), ('zprozrda', 'zprozrda.gov.ua'), ('umanska-rayrada', 'umanska-rayrada.gov.ua'), ('skole-rada', 'skole-rada.gov.ua'), ('dsvv', 'dsvv.gov.ua'), ('vn-rda', 'vn-rda.gov.ua'), ('teterivska-gromada', 'teterivska-gromada.gov.ua'), ('yagotyn-osvita', 'yagotyn-osvita.gov.ua'), ('zarrda', 'zarrda.gov.ua'), ('siverska-gromada', 'siverska-gromada.gov.ua'), ('vbeloz', 'vbeloz.gov.ua'), ('lubeshivska-gromada', 'lubeshivska-gromada.gov.ua'), ('eu-ua', 'eu-ua.org'), ('kodyma-mr', 'kodyma-mr.gov.ua'), ('vingfu', 'vingfu.gov.ua'), ('rokytne-rda', 'rokytne-rda.gov.ua'), ('oleshynska-gromada', 'oleshynska-gromada.gov.ua'), ('bdpu', 'philology.bdpu.org'), ('bahmutska-rda', 'bahmutska-rda.gov.ua'), ('demydivska-gromada', 'demydivska-gromada.gov.ua'), ('dszn-zoda', 'dszn-zoda.gov.ua'), ('nads', 'nads.gov.ua'), ('kobelyaky-miskrada', 'kobelyaky-miskrada.gov.ua'), ('nemyriv-mrada', 'nemyriv-mrada.gov.ua'), ('vilnyanska-rayrada', 'vilnyanska-rayrada.gov.ua'), ('radavlasovka', 'radavlasovka.gov.ua'), ('bliznjuki-rayrada', 'bliznjuki-rayrada.gov.ua')]
#
# 34
# [('trostyanec-rayrada', 'trostyanec-rayrada.gov.ua'), ('mkrda', 'mkrda.gov.ua'), ('pischanka-rda', 'pischanka-rda.gov.ua'), ('orrda', 'orrda.gov.ua'), ('kmr', 'kmr.gov.ua'), ('lityn-administratsia', 'www.lityn-administratsia.gov.ua'), ('dpsscn', 'dpsscn.gov.ua'), ('rdabershad', 'rdabershad.gov.ua'), ('mankrda', 'mankrda.gov.ua'), ('barrda', 'barrda.gov.ua'), ('dsp', 'dp.dsp.gov.ua'), ('pogrda', 'pogrda.gov.ua'), ('kyivcity', 'kyivcity.gov.ua'), ('silrada', 'savyna.silrada.org.ua'), ('chudeyska-gromada', 'chudeyska-gromada.gov.ua'), ('sokyryanska-gromada', 'sokyryanska-gromada.gov.ua'), ('tulchin-rda', 'tulchin-rda.gov.ua'), ('covid19', 'covid19.govt.nz'), ('karlivka-mrada', 'karlivka-mrada.gov.ua'), ('obuhivska-rayrada', 'obuhivska-rayrada.gov.ua'), ('uub', 'uub.jp'), ('adm-km', 'www.adm-km.gov.ua'), ('kanivska-rayrada', 'kanivska-rayrada.gov.ua'), ('darg', 'darg.gov.ua'), ('novopskovska-rayrada', 'novopskovska-rayrada.gov.ua'), ('tomrayrada', 'tomrayrada.gov.ua'), ('merefaotg', 'merefaotg.gov.ua'), ('oleksandrivka-gromada', 'oleksandrivka-gromada.gov.ua'), ('tyvrivska-rda', 'tyvrivska-rda.gov.ua'), ('troicka-gromada', 'troicka-gromada.gov.ua'), ('chornobay-rda', 'chornobay-rda.gov.ua'), ('ladyzhynska-gromada', 'ladyzhynska-gromada.gov.ua'), ('skole-rda', 'skole-rda.gov.ua'), ('loda', 'loda.gov.ua')]
#
# 11
# [('ejpam', 'ejpam.com'), ('hrjournal', 'hrjournal.net'), ('jumdjournal', 'jumdjournal.net'), ('vpjournal', 'vpjournal.net'), ('ejmathsci', 'ejmathsci.org'), ('cdrjournal', 'cdrjournal.com'), ('misjournal', 'misjournal.net'), ('jcmtjournal', 'jcmtjournal.com'), ('sdsjournal', 'sdsjournal.com'), ('jtggjournal', 'jtggjournal.com'), ('parjournal', 'parjournal.net')]
#
# 39
# [('geosci-commun-discuss', 'www.geosci-commun-discuss.net'), ('biogeosciences', 'www.biogeosciences.net'), ('hydrol-earth-syst-sci', 'www.hydrol-earth-syst-sci.net'), ('nat-hazards-earth-syst-sci', 'www.nat-hazards-earth-syst-sci.net'), ('soil-journal', 'www.soil-journal.net'), ('proc-iahs', 'www.proc-iahs.net'), ('ann-geophys-discuss', 'www.ann-geophys-discuss.net'), ('earth-surf-dynam', 'www.earth-surf-dynam.net'), ('solid-earth', 'www.solid-earth.net'), ('earth-syst-sci-data', 'www.earth-syst-sci-data.net'), ('earth-syst-sci-data-discuss', 'www.earth-syst-sci-data-discuss.net'), ('int-arch-photogramm-remote-sens-spatial-inf-sci', 'www.int-arch-photogramm-remote-sens-spatial-inf-sci.net'), ('atmos-meas-tech', 'www.atmos-meas-tech.net'), ('earth-syst-dynam-discuss', 'www.earth-syst-dynam-discuss.net'), ('nat-hazards-earth-syst-sci-discuss', 'www.nat-hazards-earth-syst-sci-discuss.net'), ('ocean-sci-discuss', 'www.ocean-sci-discuss.net'), ('atmos-chem-phys-discuss', 'www.atmos-chem-phys-discuss.net'), ('geosci-commun', 'www.geosci-commun.net'), ('nonlin-processes-geophys-discuss', 'www.nonlin-processes-geophys-discuss.net'), ('proc-int-cartogr-assoc', 'www.proc-int-cartogr-assoc.net'), ('earth-syst-dynam', 'www.earth-syst-dynam.net'), ('nonlin-processes-geophys', 'www.nonlin-processes-geophys.net'), ('hydrol-earth-syst-sci-discuss', 'www.hydrol-earth-syst-sci-discuss.net'), ('geosci-instrum-method-data-syst-discuss', 'www.geosci-instrum-method-data-syst-discuss.net'), ('geosci-model-dev-discuss', 'www.geosci-model-dev-discuss.net'), ('geosci-instrum-method-data-syst', 'www.geosci-instrum-method-data-syst.net'), ('adv-geosci', 'www.adv-geosci.net'), ('clim-past-discuss', 'www.clim-past-discuss.net'), ('abstr-int-cartogr-assoc', 'www.abstr-int-cartogr-assoc.net'), ('hist-geo-space-sci', 'www.hist-geo-space-sci.net'), ('earth-surf-dynam-discuss', 'www.earth-surf-dynam-discuss.net'), ('atmos-chem-phys', 'www.atmos-chem-phys.net'), ('biogeosciences-discuss', 'www.biogeosciences-discuss.net'), ('the-cryosphere', 'www.the-cryosphere.net'), ('clim-past', 'www.clim-past.net'), ('geosci-model-dev', 'www.geosci-model-dev.net'), ('geochronology-discuss', 'www.geochronology-discuss.net'), ('atmos-meas-tech-discuss', 'www.atmos-meas-tech-discuss.net'), ('ocean-sci', 'www.ocean-sci.net')]
#
# 41
# [('bu', 'link.bu.edu'), ('awm', 'pwiki.awm.jp'), ('eui', 'link.library.eui.eu'), ('rta', 'journals.rta.lv'), ('romanischestudien', 'www.romanischestudien.de'), ('nsw', 'link.randwick.nsw.gov.au'), ('earthbound', 'earthbound.report'), ('uchicago', 'annie.uchicago.edu'), ('nyu', 'confluence.gallatin.nyu.edu'), ('ceec', 'collego.ceec.edu.tw'), ('datsip', 'www.datsip.qld.gov.au'), ('aragonvalley', 'www.aragonvalley.com'), ('cam', 'www.cam.ac.uk'), ('ucsd', 'flagella.crbs.ucsd.edu'), ('asu', 'journal.asu.ru'), ('getty', 'blogs.getty.edu'), ('digital', 'digital.report'), ('mundoasperger', 'www.mundoasperger.com'), ('usg', 'oer.galileo.usg.edu'), ('upenn', 'link.law.upenn.edu'), ('xn--80abaqzevto0rc', 'www.xn--80abaqzevto0rc.xn--j1amh'), ('biaswatchneuro', 'biaswatchneuro.com'), ('waterconnect', 'www.waterconnect.sa.gov.au'), ('core', 'blog.core.ac.uk'), ('byu', 'link.lib.byu.edu'), ('cambridge', 'core-cms.prod.aop.cambridge.org'), ('ingentaconnect', 'www.ingentaconnect.com'), ('yliopistopedagogiikka', 'lehti.yliopistopedagogiikka.fi'), ('taxworkinggroup', 'taxworkinggroup.govt.nz'), ('ucla', 'link.library.ucla.edu'), ('peerj', 'peerj.com'), ('space-awareness', 'www.space-awareness.org'), ('scu', 'jrmbs.scu.ac.ir'), ('kosmonautix', 'www.kosmonautix.cz'), ('octave', 'wiki.octave.org'), ('asm', 'msystems.asm.org'), ('psu', 'www.e-education.psu.edu'), ('britannica', 'blogs.britannica.com'), ('mrc', 'www.bpod.mrc.ac.uk'), ('cmc', 'jcmc.cmc.edu.np'), ('columbia', 'journals.library.columbia.edu')]
#
# 45
# [('ajol', 'www.ajol.info'), ('juniperpublishers', 'juniperpublishers.com'), ('cjournal', 'www.cjournal.cz'), ('biomedres', 'biomedres.us'), ('ecronicon', 'www.ecronicon.com'), ('ijcce', 'www.ijcce.ac.ir'), ('clinmedjournals', 'clinmedjournals.org'), ('utb', 'dspace.utb.edu.ec'), ('jcema', 'www.jcema.com'), ('emmind', 'emmind.net'), ('unad', 'hemeroteca.unad.edu.co'), ('inamu', 'www.inamu.go.cr'), ('businessperspectives', 'businessperspectives.org'), ('madridge', 'madridge.org'), ('mutatice', 'mutatice.net'), ('rajournals', 'www.rajournals.in'), ('ijddr', 'www.ijddr.in'), ('gjesm', 'www.gjesm.net'), ('sru', 'jcarme.sru.ac.ir'), ('sciepub', 'www.sciepub.com'), ('zbornica-zveza', 'obzornik.zbornica-zveza.si'), ('sjweh', 'www.sjweh.fi'), ('dinodata', 'dinodata.de'), ('ump', 'jurnalnasional.ump.ac.id'), ('ciard', 'ring.ciard.net'), ('crimsonpublishers', 'crimsonpublishers.com'), ('scirp', 'www.scirp.org'), ('giapjournals', 'giapjournals.com'), ('lstmed', 'archive.lstmed.ac.uk'), ('worktribe', 'uwe-repository.worktribe.com'), ('scholarena', 'fulltext.scholarena.co'), ('sciencepublishinggroup', 'www.sciencepublishinggroup.com'), ('unhas', 'journal.unhas.ac.id'), ('rilem', 'letters.rilem.net'), ('academicjournals', 'academicjournals.org'), ('ommegaonline', 'www.ommegaonline.org'), ('rbmfc', 'www.rbmfc.org.br'), ('vgtu', 'journals.vgtu.lt'), ('ijhcum', 'www.ijhcum.net'), ('omicsonline', 'www.omicsonline.org'), ('ajas', 'www.ajas.info'), ('kanker-actueel', 'kanker-actueel.nl'), ('actascientific', 'actascientific.com'), ('materialscloud', 'archive.materialscloud.org'), ('ubb', 'berumpun.ubb.ac.id')]
#
# 42
# [('palrap', 'palrap.org'), ('onetcodeconnector', 'www.onetcodeconnector.org'), ('portlandpress', 'portlandpress.com'), ('dassh', 'www.dassh.ac.uk'), ('geoscienceworld', 'pubs.geoscienceworld.org'), ('edp-open', 'epjam.edp-open.org'), ('zbw', 'zbw.eu'), ('onetonline', 'www.onetonline.org'), ('naturvardsverket', 'naturvardsverket.se'), ('mynextmove', 'www.mynextmove.org'), ('onetcenter', 'www.onetcenter.org'), ('sobecc', 'revista.sobecc.org.br'), ('techscience', 'techscience.com'), ('regione', 'opendata.regione.sardegna.it'), ('edpsciences', 'cfmetrologie.edpsciences.org'), ('openaccesspub', 'openaccesspub.org'), ('iwaponline', 'iwaponline.com'), ('getsongbpm', 'getsongbpm.com'), ('qgcio', 'www.qgcio.qld.gov.au'), ('antweb', 'www.antweb.org'), ('conferenceindex', 'www.conferenceindex.org'), ('abas', 'aguassubterraneas.abas.org'), ('transport', 'data.transport.tn'), ('fareast', 'brt.fareast.mobi'), ('unocha', 'fts.unocha.org'), ('socine', 'rebeca.socine.org.br'), ('aanda', 'www.aanda.org'), ('heighpubs', 'www.heighpubs.org'), ('cdlib', 'registry.cdlib.org'), ('unideb', 'ojs.lib.unideb.hu'), ('brtdata', 'www.brtdata.net'), ('pensoft', 'checklist.pensoft.net'), ('newprairiepress', 'newprairiepress.org'), ('udesc', 'revistas.udesc.br'), ('journalijar', 'www.journalijar.com'), ('mlpmerch', 'data.mlpmerch.com'), ('estudosinstitucionais', 'estudosinstitucionais.com'), ('swsc-journal', 'www.swsc-journal.org'), ('runaway', 'runaway.university'), ('waset', 'panel.waset.org'), ('humanitarianresponse', 'www.humanitarianresponse.info'), ('hpc', 'assessments.hpc.tools')]
#
# 12
# [('monon', 'link.monon.lib.in.us'), ('mhtpl', 'link.mhtpl.lib.in.us'), ('andrews', 'link.andrews.lib.in.us'), ('lintonpl', 'link.lintonpl.lib.in.us'), ('monticello', 'link.monticello.lib.in.us'), ('lincolnheritage', 'link.lincolnheritage.lib.in.us'), ('upland', 'link.upland.lib.in.us'), ('arapahoelibraries', 'link.arapahoelibraries.org'), ('westlebanon', 'link.westlebanon.lib.in.us'), ('waterloo', 'link.waterloo.lib.in.us'), ('nh', 'link.dover.nh.gov'), ('gmu', 'chnm.gmu.edu')]
#
# 26
# [('ocl-journal', 'www.ocl-journal.org'), ('sicot-j', 'www.sicot-j.org'), ('ijsmdo', 'www.ijsmdo.org'), ('esomat', 'www.esomat.org'), ('parasite-journal', 'www.parasite-journal.org'), ('photoniques', 'www.photoniques.com'), ('mechanics-industry', 'www.mechanics-industry.org'), ('vtlmi', 'www.vtlmi.info'), ('sardegnaelezioni', 'www.sardegnaelezioni.it'), ('metrology-journal', 'www.metrology-journal.org'), ('j3ea', 'www.j3ea.org'), ('radioprotection', 'www.radioprotection.org'), ('medecinesciences', 'www.medecinesciences.org'), ('eucass-proceedings', 'www.eucass-proceedings.eu'), ('4open-sciences', 'www.4open-sciences.org'), ('bsgf', 'www.bsgf.fr'), ('rees-journal', 'www.rees-journal.org'), ('jnwpu', 'www.jnwpu.org'), ('esaim-proc', 'www.esaim-proc.org'), ('esaim-ps', 'www.esaim-ps.org'), ('ifpenergiesnouvelles', 'ogst.ifpenergiesnouvelles.fr'), ('jomos', 'www.jomos.org'), ('epj-pv', 'www.epj-pv.org'), ('regenmedres-journal', 'www.regenmedres-journal.org'), ('cahiers-myologie', 'www.cahiers-myologie.org'), ('epj-n', 'www.epj-n.org')]
#
# 14
# [('plos', 'journals.plos.org'), ('springernature', 'grandchallenges.springernature.com'), ('springeropen', 'ecologicalprocesses.springeropen.com'), ('scielosp', 'scielosp.org'), ('sciforum', 'sciforum.net'), ('scielo', 'www.scielo.org.za'), ('biomedcentral', 'bmcneurosci.biomedcentral.com'), ('nature', 'www.nature.com'), ('elifesciences', 'elifesciences.org'), ('frontiersin', 'www.frontiersin.org'), ('springer', 'rd.springer.com'), ('preprints', 'www.preprints.org'), ('beds', '0-bmcpsychiatry-biomedcentral-com.brum.beds.ac.uk'), ('mdpi', 'www.mdpi.com')]
#
# 4
# [('virginiamemory', 'link.virginiamemory.com'), ('4cls', 'link.4cls.org'), ('sirsi', 'link.bed.ent.sirsi.net'), ('mvlc', 'link.mvlc.org')]
#
# 31
# ...
#
# 10
# [('mpnews', 'www.mpnews.it'), ('dovevoandareinterapia', 'www.dovevoandareinterapia.it'), ('poliziadistato', 'questure.poliziadistato.it'), ('speedycreativa', 'www.speedycreativa.com'), ('interno', 'www1.interno.gov.it'), ('kataweb', 'silviotera.blog.kataweb.it'), ('aib', 'riviste.aib.it'), ('maestroantonio', 'www.maestroantonio.it'), ('informazione', 'www.informazione.tv'), ('susyskitchen', 'www.susyskitchen.it')]
#
# 14
# [('apxe', 'apxe.eu'), ('viurealspirineus', 'www.viurealspirineus.cat'), ('territoris', 'www.territoris.cat'), ('index', 'forum.index.hu'), ('patepis', 'patepis.com'), ('smvk', 'collections.smvk.se'), ('kaksepishe', 'kaksepishe.com'), ('craftcurry', 'www.craftcurry.com'), ('scrivere', 'danilotropeano.scrivere.info'), ('elmundo', 'diariodecastillayleon.elmundo.es'), ('rimescelte', 'rimescelte.com'), ('palmistryforyou', 'palmistryforyou.com'), ('svobodnaplaneta', 'svobodnaplaneta.com'), ('13cg', 'www.13cg.com')]
#
# 60
# [('privacylawyer', 'blog.privacylawyer.ca'), ('olinews', 'www.olinews.info'), ('mentaeliquirizia', 'www.mentaeliquirizia.com'), ('giusec', 'www.giusec.net'), ('evilripper', 'www.evilripper.net'), ('dotmac', 'dotmac.net'), ('a6fanzine', 'www.a6fanzine.it'), ('partecipasalute', 'www.partecipasalute.it'), ('valentano', 'www.valentano.net'), ('oltreilcancro', 'oltreilcancro.it'), ('lostinkitchen', 'www.lostinkitchen.com'), ('ambientebio', 'www.ambientebio.it'), ('rivistapaginauno', 'www.rivistapaginauno.it'), ('shirdisaibabastories', 'www.shirdisaibabastories.org'), ('mandalaevolutivo', 'mandalaevolutivo.com'), ('frontieratv', 'www.frontieratv.it'), ('yoextranjero', 'yoextranjero.com'), ('nonsolobelcanto', 'nonsolobelcanto.com'), ('cronacheancona', 'www.cronacheancona.it'), ('odolo', 'comune.odolo.bs.it'), ('singloids', 'singloids.blog'), ('sparidinchiostro', 'sparidinchiostro.com'), ('aetnanet', 'www.aetnanet.org'), ('kaints', 'www.kaints.com'), ('lareginadelsapone', 'www.lareginadelsapone.com'), ('cronachemaceratesi', 'www.cronachemaceratesi.it'), ('libreriecad', 'www.libreriecad.it'), ('scienzenoetiche', 'www.scienzenoetiche.it'), ('liberipensatori', 'liberipensatori.org'), ('finestrasulweb', 'www.finestrasulweb.com'), ('storieenotizie', 'www.storieenotizie.com'), ('trashfood', 'trashfood.com'), ('metalskunk', 'metalskunk.com'), ('elapsus', 'www.elapsus.it'), ('libera-mente', 'www.libera-mente.net'), ('vestone', 'comune.vestone.bs.it'), ('letattidee', 'www.letattidee.com'), ('shirdisaibabaexperiences', 'www.shirdisaibabaexperiences.org'), ('fededuepuntozero', 'www.fededuepuntozero.com'), ('sanatzione', 'www.sanatzione.eu'), ('accademiadeisensi', 'www.accademiadeisensi.it'), ('isoladiavalon', 'www.isoladiavalon.eu'), ('puntosicuro', 'www.puntosicuro.it'), ('binet', 'www.binet.tv'), ('cloudlawyer', 'www.cloudlawyer.ca'), ('simoneguidi', 'www.simoneguidi.info'), ('rifondazionelaspezia', 'www.rifondazionelaspezia.it'), ('storiesandnews', 'www.storiesandnews.net'), ('ildottoredeicomputer', 'www.ildottoredeicomputer.com'), ('matebi', 'www.matebi.it'), ('parterre', 'www.parterre.nl'), ('script-ed', 'script-ed.org'), ('agiad', 'www.agiad.it'), ('saiyugnetwork', 'prayers.saiyugnetwork.com'), ('romalive', 'romalive.biz'), ('marcucciogemel', 'www.marcucciogemel.it'), ('botskool', 'www.botskool.com'), ('transalp', 'www.transalp.it'), ('cronachediordinariorazzismo', 'www.cronachediordinariorazzismo.org'), ('vloganza', 'www.vloganza.tv')]
#
# 10
# [('ivonbacaicoa', 'www.ivonbacaicoa.com'), ('insauga', 'www.insauga.com'), ('inthehammer', 'www.inthehammer.com'), ('inhalton', 'www.inhalton.com'), ('inbrampton', 'www.inbrampton.com'), ('orientalfotosflores', 'www.orientalfotosflores.com.br'), ('flaviamelzi', 'www.flaviamelzi.com'), ('huma-num', 'cocoon.huma-num.fr'), ('altamirafotos', 'www.altamirafotos.com.br'), ('language-archives', 'search.language-archives.org')]
#
# 16
# [('podcast', 'radioalcala.podcast.es'), ('i400calci', 'www.i400calci.com'), ('spaces', 'spaces.ac.cn'), ('amlo', 'www.amlo.it'), ('milestone', 'milestone.hu'), ('gennarocarotenuto', 'www.gennarocarotenuto.it'), ('usta', 'repository.usta.edu.co'), ('lanostra-matematica', 'www.lanostra-matematica.org'), ('alternatives', 'journal.alternatives.ca'), ('libero', 'blog.libero.it'), ('kexue', 'kexue.fm'), ('applepiedimarypie', 'www.applepiedimarypie.com'), ('alterinter', 'www.alterinter.org'), ('altervista', 'michaelrigamonti.altervista.org'), ('shirdisaibabakripa', 'www.shirdisaibabakripa.org'), ('tutto-scienze', 'www.tutto-scienze.org')]
#
# 8
# [('matteoporopat', 'www.matteoporopat.com'), ('net-one', 'net-one.org'), ('librogame', 'www.librogame.net'), ('umanitanuova', 'umanitanuova.org'), ('healthdialogueculture', 'healthdialogueculture.org'), ('mdc-net', 'mdc-net.org'), ('focolares', 'www.focolares.org.br'), ('iginogiordani', 'www.iginogiordani.info')]
#
# 8
# [('focolare', 'wordteens.focolare.org'), ('comunionediritto', 'comunionediritto.org'), ('sportmeet', 'sportmeet.org'), ('livingpeaceinternational', 'livingpeaceinternational.org'), ('trentoardente', 'lnx.trentoardente.it'), ('eduforunity', 'www.eduforunity.org'), ('frpeterleung', 'frpeterleung.com'), ('ecoone', 'www.ecoone.org')]
#
# 7
# [('esercizidistretching', 'www.esercizidistretching.com'), ('exercicesdetirement', 'www.exercicesdetirement.com'), ('stretching', 'www.stretching.name'), ('estiramientos', 'www.estiramientos.es'), ('exerciciosdealongamento', 'www.exerciciosdealongamento.com'), ('pilates3', 'www.pilates3.com'), ('dehngymnastik', 'www.dehngymnastik.com')]
#
# 10
# [('spettacolidinarrazione', 'www.spettacolidinarrazione.it'), ('librisulladiversita', 'www.librisulladiversita.it'), ('librisulrazzismo', 'www.librisulrazzismo.it'), ('storiedirazzismo', 'www.storiedirazzismo.it'), ('storiediimmigrati', 'www.storiediimmigrati.it'), ('romanzieracconti', 'www.romanzieracconti.it'), ('storiediscuola', 'www.storiediscuola.it'), ('storiedidonne', 'www.storiedidonne.it'), ('rassegnateatrodinarrazione', 'www.rassegnateatrodinarrazione.it'), ('elearningnews', 'www.elearningnews.it')]
#
#
# ----------------------------------------------------------------------
#
# ('by-nc-sa', '2.0')
#
# 46
# [('hanam', 'photo.hanam.go.kr'), ('rosegardenmusic', 'rosegardenmusic.com'), ('kopinga', 'herman.kopinga.nl'), ('digitalgeography', 'www.digitalgeography.co.uk'), ('cuhk', 'www.cse.cuhk.edu.hk'), ('paxetbonum', 'paxetbonum.de'), ('lavits', 'lavits.org'), ('ecomovilidad', 'ecomovilidad.net'), ('ikso', 'lavenko.ikso.net'), ('bighugelabs', 'bighugelabs.com'), ('stadtwiki', 'en.ka.stadtwiki.net'), ('rome-en-images', 'www.rome-en-images.com'), ('circulaseguro', 'www.circulaseguro.com'), ('pages-perso', 'blogajo.pages-perso.net'), ('conservapedia', 'www.conservapedia.com'), ('homberger-hingucker', 'www.homberger-hingucker.de'), ('geneanet', 'es.geneanet.org'), ('clubtroppo', 'clubtroppo.com.au'), ('maniadb', 'www.maniadb.com'), ('oosoom', 'oosoom.org'), ('muenster', 'www.muenster.org'), ('grioo', 'www.grioo.com'), ('debianizzati', 'guide.debianizzati.org'), ('mirror', 'namu.mirror.wiki'), ('freelancis', 'freelancis.net'), ('forvo', 'eu.forvo.com'), ('nearby', 'www.nearby.org.uk'), ('hiegel', 'lastfm.hiegel.fr'), ('plain-sense', 'podcast.plain-sense.co.uk'), ('stadtwikidd', 'www.stadtwikidd.de'), ('e-d-e', 'e-d-e.org'), ('redferret', 'www.redferret.net'), ('trippenbach', 'trippenbach.com'), ('vub', 'soft.vub.ac.be'), ('robotbuzz', 'www.robotbuzz.fr'), ('freeg131', 'freeg131.com'), ('tiptipnews', 'www.tiptipnews.co.kr'), ('fluidr', 'www.fluidr.com'), ('usabilidoido', 'www.usabilidoido.com.br'), ('ous', 'sstxp.ee.ous.ac.jp'), ('diveseven', 'diveseven.com'), ('brunodulcetti', 'www.brunodulcetti.com'), ('saporedicina', 'www.saporedicina.com'), ('blowe', 'www.blowe.org.uk'), ('sasw', 'sasw.or.kr'), ('breizh-info', 'www.breizh-info.com')]
#
# 38
# [('faro', 'faro.be'), ('droff', 'droff.com'), ('michelleblanc', 'www.michelleblanc.com'), ('macbrains', 'macbrains.info'), ('lafibala', 'www.lafibala.org'), ('cemea', 'ladoc.cemea.org'), ('rewriting', 'rewriting.net'), ('duperrin', 'www.duperrin.com'), ('barijaona', 'blog.barijaona.com'), ('outsider', 'blog.outsider.ne.kr'), ('aprja', 'aprja.net'), ('velay', 'afip.velay.greta.fr'), ('jurispedia', 'fr.jurispedia.org'), ('media', 'www.media.cat'), ('georezo', 'georezo.net'), ('plafonddeverre', 'blog.plafonddeverre.fr'), ('urbanbike', 'urbanbike.com'), ('inforeseau', 'blog.inforeseau.com'), ('transmediale', 'transmediale.de'), ('leloop', 'leloop.org'), ('frdbi', 'frdbi.info'), ('se-unsa', 'notremetier.se-unsa.org'), ('epndewallonie', 'www.epndewallonie.be'), ('culturecuts', 'www.culturecuts.net'), ('bitacoravirtual', 'www.bitacoravirtual.cl'), ('arealinux', 'www.arealinux.cl'), ('biblio', 'www.biblio.at'), ('cheatography', 'cheatography.com'), ('rdl', 'rdl.de'), ('picand', 'nicolas.picand.fr'), ('knowtex', 'www.knowtex.com'), ('nrenault', 'www.nrenault.com'), ('journalatelier', 'journalatelier.com'), ('ddcom', 'ddcom.fr'), ('guitare-improvisation', 'www.guitare-improvisation.com'), ('europeanpollendatabase', 'www.europeanpollendatabase.net'), ('randomness', 'london.randomness.org.uk'), ('firejune', 'firejune.com')]
#
# 29
# [('fondation-copernic', 'wiki.fondation-copernic.org'), ('collegelesbarattes', 'www.collegelesbarattes.fr'), ('nain-t', 'irp.nain-t.net'), ('citizenpoulpe', 'www.citizenpoulpe.com'), ('lescabanesdechanteclair', 'www.lescabanesdechanteclair.com'), ('udppc', 'grenoble.udppc.asso.fr'), ('laclassedejenny', 'www.laclassedejenny.fr'), ('climbtothestars', 'climbtothestars.org'), ('cenicienta', 'cenicienta.fr'), ('labosvt', 'www.labosvt.com'), ('mysticlolly', 'www.mysticlolly.fr'), ('gonm', 'forum.gonm.org'), ('dotaddict', 'tips.dotaddict.org'), ('marcguidoni', 'www.marcguidoni.fr'), ('stylo-rouge-et-crayon-gris', 'www.stylo-rouge-et-crayon-gris.fr'), ('lamaternelledechocolatine', 'www.lamaternelledechocolatine.fr'), ('zintox', 'www.zintox.fr'), ('neoplanete', 'www.neoplanete.fr'), ('terresdecrivains', 'terresdecrivains.com'), ('presstor', 'presstor.fr'), ('raoulblanchard', 'www.raoulblanchard.fr'), ('lagrandemaikresse', 'www.lagrandemaikresse.fr'), ('bvoltaire', 'www.bvoltaire.fr'), ('cinemasie', 'www.cinemasie.com'), ('ganguenot', 'ganguenot.net'), ('theosept', 'theosept.fr'), ('snes', 'www.lyon.snes.edu'), ('culture-numerique', 'www.culture-numerique.fr'), ('journaldesvitrines', 'www.journaldesvitrines.com')]
#
# 20
# [('grainesdelivres', 'www.grainesdelivres.fr'), ('lumieresdafrique', 'www.lumieresdafrique.com'), ('apacabesancon', 'www.apacabesancon.com'), ('hautetfort', 'pavupapri.hautetfort.com'), ('guillaumedeziel', 'guillaumedeziel.com'), ('ac-paris', 'www.ac-paris.fr'), ('lewebpedagogique', 'lewebpedagogique.com'), ('classedurby66', 'www.classedurby66.fr'), ('hopto', 'dingetje.hopto.org'), ('ymeric', 'www.ymeric.com'), ('autoresdeluruguay', 'www.autoresdeluruguay.uy'), ('kwassl', 'kwassl.net'), ('imbe', 'epd.imbe.fr'), ('archivodeprensa', 'www.archivodeprensa.edu.uy'), ('processblack', 'www.processblack.com'), ('lamaisonenfolie', 'www.lamaisonenfolie.be'), ('ac-rouen', 'numeriques.spip.ac-rouen.fr'), ('ac-normandie', 'numeriques.ac-normandie.fr'), ('christallecole', 'www.christallecole.com'), ('parti-socialiste', 'saint-mande.parti-socialiste.fr')]
#
# 27
# [('reignofdarknessrpg', 'reignofdarknessrpg.com'), ('nathyrnn', 'nathyrnn.com'), ('havenrealm', 'havenrealm.com'), ('elysiumrpg', 'elysiumrpg.com'), ('lddv', 'www.lddv.com'), ('rpglink', 'aljerer.rpglink.in'), ('bootc', 'www.bootc.net'), ('warsdomain', 'www.warsdomain.com'), ('shinobibeta', 'shinobibeta.com'), ('dragoncat', 'logd.dragoncat.net'), ('vennadore', 'www.vennadore.com'), ('infommo', 'ignis.infommo.es'), ('landofnye', 'landofnye.com'), ('fandomkingdom', 'www.fandomkingdom.net'), ('willoughbyclan', 'logd.willoughbyclan.com'), ('silverwine', 'silverwine.org'), ('digsys', 'lotgd.digsys.bg'), ('hogwartslive', 'www.hogwartslive.com'), ('lotgd4adults2', 'lotgd4adults2.com'), ('dragonsofmyth', 'dragonsofmyth.com'), ('simplenation', 'simplenation.org'), ('eq-gildenhaus', 'lotgd.eq-gildenhaus.de'), ('green-dragon', 'green-dragon.info'), ('chantrell', 'nathan.chantrell.net'), ('the-complex', 'the-complex.net'), ('hypnodragon', 'hypnodragon.de'), ('shinobilegends', 'shinobilegends.com')]
#
# 6
# [('builtinmtl', 'builtinmtl.com'), ('startups-list', 'seattle.startups-list.com'), ('namu', 'namu.moe'), ('boulderstartups', 'boulderstartups.net'), ('foog', 'foog.com'), ('economicview', 'economicview.net')]
#
# 9
# [('antimili-youth', 'www.antimili-youth.net'), ('mamamiiia', 'www.mamamiiia.com'), ('jochenlueders', 'www.jochenlueders.de'), ('owni', 'lazarus.owni.fr'), ('wri-irg', 'www.old.wri-irg.org'), ('education', 'eduscol.education.fr'), ('jochenenglish', 'www.jochenenglish.de'), ('berlinergazette', 'berlinergazette.de'), ('homeip', 'dingetje.homeip.net')]
#
# 16
# [('ruliweb', 'wiki.ruliweb.com'), ('hna', 'regiowiki.hna.de'), ('aladin', 'my.aladin.co.kr'), ('hanbiton', 'ge.hanbiton.com'), ('eichenzell-blog', 'www.eichenzell-blog.de'), ('genealogieethistoire', 'www.genealogieethistoire.com'), ('mir', 'dark.mir.pe'), ('uncyc', 'm.mirror.uncyc.org'), ('egloos', 'simugung.egloos.com'), ('rigvedawiki', 'fetch.rigvedawiki.net'), ('fork', 'fork.wiki'), ('sylphion', 'www.sylphion.net'), ('thewiki', 'thewiki.kr'), ('talkingheads', 'talkingheads.net'), ('tcatmon', 'tcatmon.com'), ('theseed', 'awiki.theseed.io')]
#
# 7
# [('scheibenwelt-convention', 'wiki.scheibenwelt-convention.de'), ('discworld-convention', 'wiki.discworld-convention.de'), ('scheibenwelt', 'www.wiki.scheibenwelt.de'), ('ankh-morpork', 'wiki.ankh-morpork.de'), ('ankh-morpork-times', 'wiki.ankh-morpork-times.de'), ('thediscworld', 'w.thediscworld.de'), ('pratchett-fanclub', 'wiki.pratchett-fanclub.de')]
#
# 4
# [('harrypotter-onlinerpg', 'www.harrypotter-onlinerpg.com'), ('x10', 'www.everworld.x10.mx'), ('lotgd', 'lotgd.de'), ('rotk', 'rotk.us')]
#
#
# ----------------------------------------------------------------------

# %% [markdown]
# ## Running Girvan-Newman

# %% [markdown]
# [Girvan-Newman](https://en.wikipedia.org/wiki/Girvan%E2%80%93Newman_algorithm) is a standard algorithm for community detection for graphs. We choose to use the built-in `networkx` implementation for convenience; we can study other algorithms for community detection later on, but right now we're still exploring the structure of the network.

# %%
# INPUT_FILE = 'fdg_input_file.json'

# %%
# g = cc_graph_ops.create_graph_from_file(INPUT_FILE)

# %%
# def most_central_edge(g):
#     centrality = nx.edge_betweenness_centrality(g, weight='weight')
#     return max(centrality, key=centrality.get)

# %%
# licenses = cc_graph_ops.get_licenses(g)

# %%
# quota = 10
# proportion = 0.3
# min_subgraph_size = 100

# %%
# subgraphs = cc_graph_ops.all_license_subgraphs(g, licenses, quota=quota, proportion=proportion)

# %%
# OUTPUT_FILE = 'communities.pkl'

# %%
# communities = dict()
# try:
#     for license in licenses:
#         if len(subgraphs[license]) < min_subgraph_size:
#             continue
#         tic = time.time()
#         print(license)
#         print('domains:', len(subgraphs[license]))
#         comp = community.centrality.girvan_newman(subgraphs[license], most_valuable_edge=most_central_edge)
#         communities[license] = tuple(sorted(c) for c in next(comp))
#         toc = time.time()
#         print('elapsed:', toc-tic)
# except KeyboardInterrupt:
#     with open(OUTPUT_FILE, 'wb') as output:
#         pickle.dump(communities, output)

# %%
# with open(OUTPUT_FILE, 'wb') as output:
#     pickle.dump(communities, output)
