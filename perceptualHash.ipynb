# %%
#pip install ImageHash

# %%
from PIL import Image

import imagehash
import tarfile
import io
import matplotlib.pyplot as plt

# %%
# Insert your own file path below
path = '../../Documents/Berkeley/Fall 2020/CC/pref_0000.tar.gz'
tf = tarfile.open(path)

num_files = 1083
img_names = tf.getnames()[0:num_files]

imgs = []
for i in range(num_files):
    img = tf.extractfile(tf.getmember(img_names[i]))
    img = img.read()
    img = Image.open(io.BytesIO(img))
    imgs.append(img)

# %%
# Perceptual hashing
hash_dict = {img_names[j]:imagehash.whash(imgs[j]) for j in range(num_files)}
hash_dist_arr = [[hash_dict[h1]-hash_dict[h2] for h1 in hash_dict] for h2 in hash_dict]

# %%
D = 2
total_close = 0
min_coords_list = []
for k in range(num_files):
    min_dist = min(hash_dist_arr[k][:k] + hash_dist_arr[k][k+1:])
    if min_dist <= D:
        total_close += 1
        min_coords = (k, hash_dist_arr[k].index(min_dist), min_dist)
        min_coords_list.append(min_coords)

# %%
display(total_close, min_coords_list)
# Out:
# 47
# [(20, 20, 0),
#  (90, 90, 0),
#  (103, 987, 2),
#  (117, 90, 2),
#  (139, 332, 2),
#  (158, 807, 2),
#  (195, 90, 0),
#  (203, 90, 0),
#  (211, 90, 2),
#  (221, 332, 2),
#  (257, 90, 2),
#  (315, 572, 2),
#  (332, 332, 0),
#  (334, 90, 0),
#  (352, 20, 0),
#  (410, 417, 2),
#  (417, 410, 2),
#  (422, 633, 2),
#  (449, 20, 0),
#  (497, 20, 0),
#  (517, 90, 0),
#  (547, 20, 0),
#  (549, 682, 2),
#  (572, 315, 2),
#  (629, 332, 2),
#  (633, 90, 2),
#  (669, 877, 2),
#  (682, 549, 2),
#  (685, 90, 2),
#  (699, 90, 0),
#  (751, 90, 0),
#  (805, 90, 0),
#  (807, 158, 2),
#  (820, 90, 2),
#  (827, 20, 0),
#  (877, 669, 2),
#  (878, 878, 0),
#  (899, 20, 0),
#  (908, 90, 0),
#  (956, 878, 0),
#  (964, 332, 0),
#  (976, 90, 0),
#  (982, 221, 2),
#  (987, 103, 2),
#  (1011, 1014, 2),
#  (1014, 1011, 2),
#  (1059, 90, 0)]

# %%
def tellme(s):
    print(s)
    plt.title(s, fontsize=16)
    plt.draw()

# %%
# %matplotlib tk
tellme('Click key if close, mouse if not close')
plt.axis('off')
plt.waitforbuttonpress()

closeness = []

for m in range(total_close):
    plt.clf()
    plt.subplot(121)
    plt.imshow(imgs[min_coords_list[m][0]])
    plt.axis('off')
    plt.subplot(122)
    plt.imshow(imgs[min_coords_list[m][1]])
    plt.axis('off')

    ans = plt.waitforbuttonpress()
    closeness.append(ans)

plt.close()

display(closeness)
# Out:
# Click key if close, mouse if not close
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-7-5b5bb2de2646> in <module>
#      15     plt.axis('off')
#      16
# ---> 17     ans = plt.waitforbuttonpress()
#      18     closeness.append(ans)
#      19
#
# c:\users\upoma\pycharmprojects\pythonproject3\venv\lib\site-packages\matplotlib\pyplot.py in waitforbuttonpress(timeout)
#    2406 @_copy_docstring_and_deprecators(Figure.waitforbuttonpress)
#    2407 def waitforbuttonpress(timeout=-1):
# -> 2408     return gcf().waitforbuttonpress(timeout=timeout)
#    2409
#    2410
#
# c:\users\upoma\pycharmprojects\pythonproject3\venv\lib\site-packages\matplotlib\figure.py in waitforbuttonpress(self, timeout)
#    2463         """
#    2464         blocking_input = BlockingKeyMouseInput(self)
# -> 2465         return blocking_input(timeout=timeout)
#    2466
#    2467     def get_default_bbox_extra_artists(self):
#
# c:\users\upoma\pycharmprojects\pythonproject3\venv\lib\site-packages\matplotlib\blocking_input.py in __call__(self, timeout)
#     352         """
#     353         self.keyormouse = None
# --> 354         BlockingInput.__call__(self, n=1, timeout=timeout)
#     355
#     356         return self.keyormouse
#
# c:\users\upoma\pycharmprojects\pythonproject3\venv\lib\site-packages\matplotlib\blocking_input.py in __call__(self, n, timeout)
#      91         try:
#      92             # Start event loop.
# ---> 93             self.fig.canvas.start_event_loop(timeout=timeout)
#      94         finally:  # Run even on exception like ctrl-c.
#      95             # Disconnect the callbacks.
#
# c:\users\upoma\pycharmprojects\pythonproject3\venv\lib\site-packages\matplotlib\backend_bases.py in start_event_loop(self, timeout)
#    2405         self._looping = True
#    2406         while self._looping and counter * timestep < timeout:
# -> 2407             self.flush_events()
#    2408             time.sleep(timestep)
#    2409             counter += 1
#
# c:\users\upoma\pycharmprojects\pythonproject3\venv\lib\site-packages\matplotlib\backends\_backend_tk.py in flush_events(self)
#     388     def flush_events(self):
#     389         # docstring inherited
# --> 390         self._master.update()
#     391
#     392
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\tkinter\__init__.py in update(self)
#    1303     def update(self):
#    1304         """Enter event loop until all pending events have been processed by Tcl."""
# -> 1305         self.tk.call('update')
#    1306
#    1307     def update_idletasks(self):
#
# TclError: can't invoke "update" command: application has been destroyed
